# %% [markdown]
# # Linear Regression (Sklearn)

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ### Load Dataset

# %%
data = np.loadtxt('data.txt')

X = data[:,0].reshape(-1,1)
y = data[:,1]

# %% [markdown]
# ### Visualizing Raw dataset

# %%
plt.scatter(X,y)
plt.xlabel("Size (sqft)")
plt.ylabel("Price")
plt.title("House Prices")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Train sklearn model

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Coefficients + Intercept

# %%
w = model.coef_[0]
b = model.intercept_

print(f"Weight is: {w}\n bias is: {b}")
# Out:
# Weight is: 179.2615407491623
#  bias is: -14775.665733963659

# %% [markdown]
# ### Making Predictions

# %%
y_pred = model.predict(X)

# %% [markdown]
# ### Regression line

# %%
plt.scatter(X,y, color = 'blue', label = 'Actual')
plt.plot(X,y_pred, color = 'red', label = 'Predicted')

plt.xlabel("size")
plt.ylabel("price")
plt.title("Linear Regression(Sklearn)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Evaluate Model

# %%
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R² Score:", r2)
# Out:
# RMSE: 37629.23853690144
# MAE: 33389.21804885112
# R² Score: 0.854244332846411
